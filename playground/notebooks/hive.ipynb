# %%
from dotenv import load_dotenv
import os
from pathlib import Path
import psycopg2 as pg


# Load environment variables
ENV_PATH = "./.env"
load_dotenv(ENV_PATH)
# Out:
# False

# %%
from pyhive import hive
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, date_format, when
import pandas as pd
from sqlalchemy import create_engine, text
from sqlalchemy.exc import SQLAlchemyError
import shutil

db_host = os.getenv("POSTGRES_HOST","localhost")
db_port = os.getenv("POSTGRES_PORT","1200")
db_user = os.getenv("POSTGRES_USER","postgres")
db_password = os.getenv("POSTGRES_PASSWORD","postgres")
db_database = os.getenv("POSTGRES_DATABASE","test")

# Create a connection to the PostgreSQL database
pg_engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_database}')

etl_restaurant_statement = """
    with 
    lastest_dt_restaurant as (
        SELECT restaurant_id, max(TO_CHAR(order_created_timestamp,'YYYYMMDD')) as dt 
        FROM public.order_detail
        GROUP BY restaurant_id
    )

    select rd.*, ldr.dt
    from public.restaurant_detail rd
    left join lastest_dt_restaurant ldr on rd.id = ldr.restaurant_id
"""

spark = SparkSession.builder \
    .appName("test") \
    .config("spark.hadoop.hive.metastore.uris", "thrift://localhost:9083") \
    .config("spark.sql.warehouse.dir", "/opt/hive/warehouse") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .enableHiveSupport() \
    .getOrCreate()


with pg_engine.connect() as pg_conn:
    pg_conn.begin()
    # df_restaurant = pd.read_sql_query(etl_restaurant_statement, pg_conn)
    # spark_df_restaurant = spark.createDataFrame(df_restaurant)
    # spark_df_restaurant.write.mode("overwrite").format("parquet").partitionBy("dt").saveAsTable("restaurant_detail")

    df_order_detail = pd.read_sql_query("select * from order_detail", pg_conn)
    spark_df_order = spark.createDataFrame(df_order_detail) 
    spark_df_order = spark_df_order.withColumn("dt", date_format(col("order_created_timestamp"),"yyyymmdd"))
    spark_df_order.write.mode("overwrite").format("parquet").partitionBy("dt").saveAsTable("order_detail")
    pg_conn.commit()
    pg_conn.close()
# Out:
# 23/12/10 15:25:12 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 23/12/10 15:25:33 WARN TaskSetManager: Stage 0 contains a task of very large size (1142 KiB). The maximum recommended task size is 1000 KiB.
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 98.06% for 31 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 95.00% for 32 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 92.12% for 33 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 89.41% for 34 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 86.86% for 35 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 84.44% for 36 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 82.16% for 37 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 80.00% for 38 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 77.95% for 39 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 76.00% for 40 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 74.15% for 41 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 72.38% for 42 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 70.70% for 43 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 69.09% for 44 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 67.56% for 45 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 66.09% for 46 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 64.68% for 47 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 63.33% for 48 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 62.04% for 49 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 60.80% for 50 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 59.61% for 51 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 58.46% for 52 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 57.36% for 53 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 56.30% for 54 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 55.27% for 55 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 54.29% for 56 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 53.33% for 57 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 52.41% for 58 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 51.53% for 59 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 50.67% for 60 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 49.84% for 61 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 49.03% for 62 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 48.25% for 63 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 47.50% for 64 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 48.25% for 63 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 49.03% for 62 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 49.84% for 61 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 50.67% for 60 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 51.53% for 59 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 52.41% for 58 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 53.33% for 57 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 54.29% for 56 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 55.27% for 55 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 56.30% for 54 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 57.36% for 53 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 58.46% for 52 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 59.61% for 51 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 60.80% for 50 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 62.04% for 49 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 63.33% for 48 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 64.68% for 47 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 66.09% for 46 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 67.56% for 45 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 69.09% for 44 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 70.70% for 43 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 72.38% for 42 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 74.15% for 41 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 76.00% for 40 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 77.95% for 39 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 80.00% for 38 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 82.16% for 37 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 84.44% for 36 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 86.86% for 35 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 89.41% for 34 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 92.12% for 33 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 95.00% for 32 writers
# 23/12/10 15:25:37 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 98.06% for 31 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 98.06% for 31 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 95.00% for 32 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 92.12% for 33 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 95.00% for 32 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 92.12% for 33 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 95.00% for 32 writers
# 23/12/10 15:27:33 WARN MemoryManager: Total allocation exceeds 95.00% (4,080,218,880 bytes) of heap memory
# Scaling row group sizes to 98.06% for 31 writers
# 23/12/10 15:32:48 WARN SharedInMemoryCache: Evicting cached table partition metadata from memory due to size constraints (spark.sql.hive.filesourcePartitionFileCacheSize = 262144000 bytes). This may impact query planning performance.
# 23/12/10 15:32:49 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /root/jarupong/test/playground/notebooks/hive.ipynb Cell 2 line 5
#      <a href='vscode-notebook-cell://vscode-super01.425.one/root/jarupong/test/playground/notebooks/hive.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> spark_df_order = spark_df_order.withColumn("dt", date_format(col("order_created_timestamp"),"yyyymmdd"))
#      <a href='vscode-notebook-cell://vscode-super01.425.one/root/jarupong/test/playground/notebooks/hive.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> spark_df_order.write.mode("overwrite").format("parquet").partitionBy("dt").saveAsTable("order_detail")
# ---> <a href='vscode-notebook-cell://vscode-super01.425.one/root/jarupong/test/playground/notebooks/hive.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a> pg_conn.commit()
#      <a href='vscode-notebook-cell://vscode-super01.425.one/root/jarupong/test/playground/notebooks/hive.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a> pg_conn.close()
#
# AttributeError: 'Connection' object has no attribute 'commit'

# %%
spark_df_order_new = spark.sql("SELECT * FROM order_detail")
spark_df_order_new = spark_df_order_new.withColumn("discount_no_null", col("discount")).fillna(0)
spark_df_order_new.write.mode("overwrite").saveAsTable("__order_detail_new__")

# %%
spark_df_order_new.printSchema()

# %%
spark_df_restaurant_new = spark.sql("SELECT * FROM restaurant_detail")
spark_df_restaurant_new = spark_df_restaurant_new.withColumn(
    "cooking_bin", 
    when(col("esimated_cooking_time").between(1,40),1)
    .when(col("esimated_cooking_time").between(41,80),2)
    .when(col("esimated_cooking_time").between(81,120),3)
    .when(col("esimated_cooking_time")>120,4)
    .otherwise(0)
)
spark_df_restaurant_new.write.mode("overwrite").saveAsTable("__restaurant_detail_new__")

# %%
spark_df_restaurant_new.show()

# %%
spark_df_restaurant.printSchema()

# %%
spark_df_order_new.printSchema()

# %%
statement = """
    SELECT res.category, AVG(order.discount_no_null) AS avg_discount
    FROM __order_detail_new__ AS order
    LEFT JOIN restaurant_detail AS res ON order.restaurant_id = res.id
    GROUP BY res.category
"""

df = spark.sql(statement)
df.write.csv("../sql_requirements/avg_discount_by_category", header=True)

# %%
statement = """
    SELECT cooking_bin, COUNT(*) as row_count
    FROM __restaurant_detail_new__
    GROUP BY cooking_bin
"""

df = spark.sql(statement)
df.write.csv("../sql_requirements/row_count_by_cooking_bin", header=True)

# %%
df.show()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
            .appName("test") \
            .config("spark.master", "local[*]") \
            .config("spark.hadoop.hive.metastore.uris", "thrift://localhost:9083") \
            .config("spark.sql.warehouse.dir", "/opt/hive/warehouse") \
            .config("spark.driver.memory", "4g") \
            .config("spark.executor.memory", "4g") \
            .enableHiveSupport() \
            .getOrCreate()
